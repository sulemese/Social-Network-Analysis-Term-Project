# %%
import numpy as np
import pandas as pd
import networkx as nx

istt = nx.Graph()

print(istt)

ilçeler=["Arnavutköy", "Ataşehir", "Avcılar", "Bağcılar", "Bahçelievler",
                   "Bakırköy", "Başakşehir", "Bayrampaşa", "Beşiktaş", "Beykoz", "Beylikdüzü",
                   "Beyoğlu", "Büyükçekmece", "Çatalca", "Çekmeköy", "Esenler", "Esenyurt",
                   "Eyüpsultan", "Fatih", "Gaziosmanpaşa", "Güngören", "Kadıköy", "Kağıthane",
                   "Kartal", "Küçükçekmece", "Maltepe", "Pendik", "Sancaktepe", "Sarıyer",
                   "Silivri", "Sultanbeyli", "Sultangazi", "Şile", "Şişli", "Tuzla", "Ümraniye",
                   "Üsküdar", "Zeytinburnu",'15 Temmuz Şehitler Köprüsü(1.)','Fatih Sultan Mehmet Köprüsü(2.)','Yavuz Sultan Selim Köprüsü(3.)','Avrasya Tüneli']
istt.add_nodes_from(ilçeler)
print(istt)
# Out:
# Graph with 0 nodes and 0 edges
# Graph with 42 nodes and 0 edges

# %%
#nx.draw(istt)
nx.draw(istt, node_color='r', edge_color='b', with_labels=True, node_shape='s', style='--')
print(istt)
# Out:
# Graph with 42 nodes and 0 edges

# %%
baglantılar = [
    ("Silivri", "Büyükçekmece", {"name": "D100"}),
    ("Büyükçekmece", "Beylikdüzü", {"name": "E5"}),
    ("Beylikdüzü", "Avcılar", {"name": "E5"}),
    ("Avcılar", "Küçükçekmece", {"name": "E5"}),
    ("Küçükçekmece", "Bahçelievler", {"name": "E5"}),
    ("Bahçelievler", "Güngören", {"name": "E5"}),
    ("Güngören", "Bakırköy", {"name": "E5"}),
    ("Bakırköy", "Bahçelievler", {"name": "E5"}),
    ("Bakırköy", "Zeytinburnu", {"name": "E5"}),
    ("Güngören", "Zeytinburnu", {"name": "E5"}),
    ("Zeytinburnu", "Fatih", {"name": "E5"}),
    ("Fatih", "Avrasya Tüneli", {"name": "Kennedy Cad."}),
    ("Silivri", "Çatalca", {"name": "O.7"}),
    ("Silivri", "Esenyurt", {"name": "E80"}),
    ("Esenyurt", "Arnavutköy", {"name": "E80"}),
    ("Büyükçekmece", "Çatalca", {"name": "D569"}),
    ("Çatalca", "Arnavutköy", {"name": "D020"}),
    ("Çatalca", "Arnavutköy", {"name": "O.7"}),
    ("Arnavutköy", "Sarıyer", {"name": "O.7"}),
    ("Sarıyer", "Yavuz Sultan Selim Köprüsü(3.)", {"name": "O.7"}),
    ("Arnavutköy", "Eyüpsultan", {"name": "D020"}),
    ("Eyüpsultan", "Kağıthane", {"name": "E80"}),
    ("Kağıthane", "Beşiktaş", {"name": "E80"}),
    ("Beşiktaş", "Sarıyer", {"name": "E80"}),
    ("Arnavutköy", "Sultangazi", {"name": "O.7"}),
    ("Sultangazi", "Başakşehir", {"name": "O.7"}),
    ("Sultangazi", "Gaziosmanpaşa", {"name": "E80"}),
    ("Gaziosmanpaşa", "Eyüpsultan", {"name": "E80"}),
    ("Sultangazi", "Eyüpsultan", {"name": "O.7"}),
    ("Başakşehir", "Küçükçekmece", {"name": "O.7"}),
    ("Esenyurt", "Avcılar", {"name": "E80"}),
    ("Avcılar", "Küçükçekmece", {"name": "E80"}),
    ("Küçükçekmece", "Bağcılar", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "O.3"}),
    ("Gaziosmanpaşa", "Esenler", {"name": "E80"}),
    ("Esenler", "Bayrampaşa", {"name": "O.3"}),
    ("Bayrampaşa", "Fatih", {"name": "O.3"}),
    ("Fatih", "Beyoğlu", {"name": "O.1"}),
    ("Beyoğlu", "Şişli", {"name": "O.1"}),
    ("Beyoğlu", "Kağıthane", {"name": "Hasdal O.B."}),
    ("Şişli", "Beşiktaş", {"name": "O.1"}),
    ("Beşiktaş", "15 Temmuz Şehitler Köprüsü(1.)", {"name": "O.1"}),
    ("Sarıyer", "Fatih Sultan Mehmet Köprüsü(2.)", {"name": "E80"}),
]

istt.add_edges_from(baglantılar)
import matplotlib.pyplot as plt

# Grafı çizelim
plt.figure(figsize=(35, 20))

node_color = 'red'
edge_color = 'black'
edge_labels = nx.get_edge_attributes(istt, 'name')

nx.draw(istt, pos=nx.spring_layout(istt), with_labels=True, node_size=5000, node_color=node_color, edge_color=edge_color, font_size=10, font_color='white', font_weight='bold')

# Edgelerin üzerine label'ları ekleyelim
nx.draw_networkx_edge_labels(istt, pos=nx.spring_layout(istt), edge_labels=edge_labels, font_color='black',font_size=15)

plt.title('Özel Graf Çizimi')
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Grafı oluştur
istt = nx.Graph()

ilçeler = ["Arnavutköy", "Ataşehir", "Avcılar", "Bağcılar", "Bahçelievler",
           "Bakırköy", "Başakşehir", "Bayrampaşa", "Beşiktaş", "Beykoz", "Beylikdüzü",
           "Beyoğlu", "Büyükçekmece", "Çatalca", "Çekmeköy", "Esenler", "Esenyurt",
           "Eyüpsultan", "Fatih", "Gaziosmanpaşa", "Güngören", "Kadıköy", "Kağıthane",
           "Kartal", "Küçükçekmece", "Maltepe", "Pendik", "Sancaktepe", "Sarıyer",
           "Silivri", "Sultanbeyli", "Sultangazi", "Şile", "Şişli", "Tuzla", "Ümraniye",
           "Üsküdar", "Zeytinburnu", '15 Temmuz Şehitler Köprüsü(1.)', 'Fatih Sultan Mehmet Köprüsü(2.)',
           'Yavuz Sultan Selim Köprüsü(3.)', 'Avrasya Tüneli']

istt.add_nodes_from(ilçeler)

# Edge'leri ekle
baglantılar = [
    ("Silivri", "Büyükçekmece", {"name": "D100"}),
    ("Büyükçekmece", "Beylikdüzü", {"name": "E5"}),
    ("Beylikdüzü", "Avcılar", {"name": "E5"}),
    ("Avcılar", "Küçükçekmece", {"name": "E5"}),
    ("Küçükçekmece", "Bahçelievler", {"name": "E5"}),
    ("Bahçelievler", "Güngören", {"name": "E5"}),
    ("Güngören", "Bakırköy", {"name": "E5"}),
    ("Bakırköy", "Bahçelievler", {"name": "E5"}),
    ("Bakırköy", "Zeytinburnu", {"name": "E5"}),
    ("Güngören", "Zeytinburnu", {"name": "E5"}),
    ("Zeytinburnu", "Fatih", {"name": "E5"}),
    ("Fatih", "Avrasya Tüneli", {"name": "Kennedy Cad."}),
    ("Silivri", "Çatalca", {"name": "O.7"}),
    ("Silivri", "Esenyurt", {"name": "E80"}),
    ("Esenyurt", "Arnavutköy", {"name": "E80"}),
    ("Büyükçekmece", "Çatalca", {"name": "D569"}),
    ("Çatalca", "Arnavutköy", {"name": "D020"}),
    ("Çatalca", "Arnavutköy", {"name": "O.7"}),
    ("Arnavutköy", "Sarıyer", {"name": "O.7"}),
    ("Sarıyer", "Yavuz Sultan Selim Köprüsü(3.)", {"name": "O.7"}),
    ("Arnavutköy", "Eyüpsultan", {"name": "D020"}),
    ("Eyüpsultan", "Kağıthane", {"name": "E80"}),
    ("Kağıthane", "Beşiktaş", {"name": "E80"}),
    ("Beşiktaş", "Sarıyer", {"name": "E80"}),
    ("Arnavutköy", "Sultangazi", {"name": "O.7"}),
    ("Sultangazi", "Başakşehir", {"name": "O.7"}),
    ("Sultangazi", "Gaziosmanpaşa", {"name": "E80"}),
    ("Gaziosmanpaşa", "Eyüpsultan", {"name": "E80"}),
    ("Sultangazi", "Eyüpsultan", {"name": "O.7"}),
    ("Başakşehir", "Küçükçekmece", {"name": "O.7"}),
    ("Esenyurt", "Avcılar", {"name": "E80"}),
    ("Avcılar", "Küçükçekmece", {"name": "E80"}),
    ("Küçükçekmece", "Bağcılar", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "O.3"}),
    ("Gaziosmanpaşa", "Esenler", {"name": "E80"}),
    ("Esenler", "Bayrampaşa", {"name": "O.3"}),
    ("Bayrampaşa", "Fatih", {"name": "O.3"}),
    ("Fatih", "Beyoğlu", {"name": "O.1"}),
    ("Beyoğlu", "Şişli", {"name": "O.1"}),
    ("Beyoğlu", "Kağıthane", {"name": "Hasdal O.B."}),
    ("Şişli", "Beşiktaş", {"name": "O.1"}),
    ("Beşiktaş", "15 Temmuz Şehitler Köprüsü(1.)", {"name": "O.1"}),
    ("Sarıyer", "Fatih Sultan Mehmet Köprüsü(2.)", {"name": "E80"}),

    ("Yavuz Sultan Selim Köprüsü(3.)", "Beykoz", {"name": "O.7"}),
    ("Fatih Sultan Mehmet Köprüsü(2.)", "Beykoz", {"name": "E80"}),
    ("15 Temmuz Şehitler Köprüsü(1.)", "Üsküdar", {"name": "O.1"}),
    ("Avrasya Tüneli", "Üsküdar", {"name": "D100"}),
    ("Beykoz", "Çekmeköy", {"name": "O.7"}),
    ("Çekmeköy", "Şile", {"name": "D020"}),
    ("Beykoz", "Ümraniye", {"name": "E80"}),
    ("Çekmeköy", "Ümraniye", {"name": "O.7"}),
    ("Çekmeköy", "Ümraniye", {"name": "D016"}),
    ("Çekmeköy", "Sancaktepe", {"name": "D020"}),
    ("Çekmeköy", "Sancaktepe", {"name": "Şile O."}),
    ("Üsküdar", "Ümraniye", {"name": "O.4"}),
    ("Üsküdar", "Ümraniye", {"name": "Şile O."}),
    ("Üsküdar", "Kadıköy", {"name": "D100"}),
    ("Üsküdar", "Kadıköy", {"name": "O.1"}),
    ("Üsküdar", "Ataşehir", {"name": "O.4"}),
    ("Kadıköy", "Ataşehir", {"name": "O.2"}),
    ("Kadıköy", "Maltepe", {"name": "D100"}),
    ("Maltepe", "Kartal", {"name": "D100"}),
    ("Maltepe", "Kartal", {"name": "Samandıra Kartal B."}),
    ("Sancaktepe", "Kartal", {"name": "Samandıra Kartal B."}),
    ("Ataşehir", "Sancaktepe", {"name": "E80"}),
    ("Ataşehir", "Ümraniye", {"name": "O.2"}),
    ("Ataşehir", "Ümraniye",{"name": "E80"}),
    ("Ümraniye", "Sancaktepe", {"name": "E80"}),
    ("Sancaktepe", "Pendik", {"name": "O.7"}),
    ("Sancaktepe", "Pendik", {"name": "D020"}),
    ("Sancaktepe", "Sultanbeyli", {"name": "E80"}),
    ("Sancaktepe", "Sultanbeyli", {"name": "D020"}),
    ("Pendik", "Sultanbeyli", {"name": "E80"}),
    ("Pendik", "Tuzla", {"name": "D100"}),
    ("Pendik", "Tuzla", {"name": "E80"}),
    ("Pendik", "Kartal", {"name": "D100"}),


]

istt.add_edges_from(baglantılar)

# Grafığı çiz
plt.figure(figsize=(20, 15))

# Node etiketlerini belirtmek için kullanılan bir sözlük oluştur
node_labels = {ilçe: ilçe for ilçe in ilçeler}

# Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
edge_labels = {edge[:2]: edge[2]["name"] for edge in istt.edges(data=True)}

# Node'ları ve Edge'leri çiz
pos = nx.spring_layout(istt, seed=42)  # Node'ların konumlarını belirleme
nx.draw_networkx_nodes(istt, pos, node_size=3000, node_color="blue")
nx.draw_networkx_labels(istt, pos, labels=node_labels, font_size=10, font_color="white")
nx.draw_networkx_edges(istt, pos, edge_color="gray")
nx.draw_networkx_edge_labels(istt, pos, edge_labels=edge_labels, font_size=10, font_color="red")

plt.title("İstanbul Ulaşım Ağı", size=20)
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Grafı oluştur
istt = nx.Graph()

ilçeler = ["Arnavutköy", "Ataşehir", "Avcılar", "Bağcılar", "Bahçelievler",
           "Bakırköy", "Başakşehir", "Bayrampaşa", "Beşiktaş", "Beykoz", "Beylikdüzü",
           "Beyoğlu", "Büyükçekmece", "Çatalca", "Çekmeköy", "Esenler", "Esenyurt",
           "Eyüpsultan", "Fatih", "Gaziosmanpaşa", "Güngören", "Kadıköy", "Kağıthane",
           "Kartal", "Küçükçekmece", "Maltepe", "Pendik", "Sancaktepe", "Sarıyer",
           "Silivri", "Sultanbeyli", "Sultangazi", "Şile", "Şişli", "Tuzla", "Ümraniye",
           "Üsküdar", "Zeytinburnu", '15 Temmuz Şehitler Köprüsü(1.)', 'Fatih Sultan Mehmet Köprüsü(2.)',
           'Yavuz Sultan Selim Köprüsü(3.)', 'Avrasya Tüneli']

istt.add_nodes_from(ilçeler)

# Edge'leri ekle
baglantılar = [
     ("Silivri", "Büyükçekmece", {"name": "D100"}),
    ("Büyükçekmece", "Beylikdüzü", {"name": "E5"}),
    ("Beylikdüzü", "Avcılar", {"name": "E5"}),
    ("Avcılar", "Küçükçekmece", {"name": "E5"}),
    ("Küçükçekmece", "Bahçelievler", {"name": "E5"}),
    ("Bahçelievler", "Güngören", {"name": "E5"}),
    ("Güngören", "Bakırköy", {"name": "E5"}),
    ("Bakırköy", "Bahçelievler", {"name": "E5"}),
    ("Bakırköy", "Zeytinburnu", {"name": "E5"}),
    ("Güngören", "Zeytinburnu", {"name": "E5"}),
    ("Zeytinburnu", "Fatih", {"name": "E5"}),
    ("Fatih", "Avrasya Tüneli", {"name": "Kennedy Cad."}),
    ("Silivri", "Çatalca", {"name": "O.7"}),
    ("Silivri", "Esenyurt", {"name": "E80"}),
    ("Esenyurt", "Arnavutköy", {"name": "E80"}),
    ("Büyükçekmece", "Çatalca", {"name": "D569"}),
    ("Çatalca", "Arnavutköy", {"name": "D020"}),
    ("Çatalca", "Arnavutköy", {"name": "O.7"}),
    ("Arnavutköy", "Sarıyer", {"name": "O.7"}),
    ("Sarıyer", "Yavuz Sultan Selim Köprüsü(3.)", {"name": "O.7"}),
    ("Arnavutköy", "Eyüpsultan", {"name": "D020"}),
    ("Eyüpsultan", "Kağıthane", {"name": "E80"}),
    ("Kağıthane", "Beşiktaş", {"name": "E80"}),
    ("Beşiktaş", "Sarıyer", {"name": "E80"}),
    ("Arnavutköy", "Sultangazi", {"name": "O.7"}),
    ("Sultangazi", "Başakşehir", {"name": "O.7"}),
    ("Sultangazi", "Gaziosmanpaşa", {"name": "E80"}),
    ("Gaziosmanpaşa", "Eyüpsultan", {"name": "E80"}),
    ("Sultangazi", "Eyüpsultan", {"name": "O.7"}),
    ("Başakşehir", "Küçükçekmece", {"name": "O.7"}),
    ("Esenyurt", "Avcılar", {"name": "E80"}),
    ("Avcılar", "Küçükçekmece", {"name": "E80"}),
    ("Küçükçekmece", "Bağcılar", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "O.3"}),
    ("Gaziosmanpaşa", "Esenler", {"name": "E80"}),
    ("Esenler", "Bayrampaşa", {"name": "O.3"}),
    ("Bayrampaşa", "Fatih", {"name": "O.3"}),
    ("Fatih", "Beyoğlu", {"name": "O.1"}),
    ("Beyoğlu", "Şişli", {"name": "O.1"}),
    ("Beyoğlu", "Kağıthane", {"name": "Hasdal O.B."}),
    ("Şişli", "Beşiktaş", {"name": "O.1"}),
    ("Beşiktaş", "15 Temmuz Şehitler Köprüsü(1.)", {"name": "O.1"}),
    ("Sarıyer", "Fatih Sultan Mehmet Köprüsü(2.)", {"name": "E80"}),

    ("Yavuz Sultan Selim Köprüsü(3.)", "Beykoz", {"name": "O.7"}),
    ("Fatih Sultan Mehmet Köprüsü(2.)", "Beykoz", {"name": "E80"}),
    ("15 Temmuz Şehitler Köprüsü(1.)", "Üsküdar", {"name": "O.1"}),
    ("Avrasya Tüneli", "Üsküdar", {"name": "D100"}),
    ("Beykoz", "Çekmeköy", {"name": "O.7"}),
    ("Çekmeköy", "Şile", {"name": "D020"}),
    ("Beykoz", "Ümraniye", {"name": "E80"}),
    ("Çekmeköy", "Ümraniye", {"name": "O.7"}),
    ("Çekmeköy", "Ümraniye", {"name": "D016"}),
    ("Çekmeköy", "Sancaktepe", {"name": "D020"}),
    ("Çekmeköy", "Sancaktepe", {"name": "Şile O."}),
    ("Üsküdar", "Ümraniye", {"name": "O.4"}),
    ("Üsküdar", "Ümraniye", {"name": "Şile O."}),
    ("Üsküdar", "Kadıköy", {"name": "D100"}),
    ("Üsküdar", "Kadıköy", {"name": "O.1"}),
    ("Üsküdar", "Ataşehir", {"name": "O.4"}),
    ("Kadıköy", "Ataşehir", {"name": "O.2"}),
    ("Kadıköy", "Maltepe", {"name": "D100"}),
    ("Maltepe", "Kartal", {"name": "D100"}),
    ("Maltepe", "Kartal", {"name": "Samandıra Kartal B."}),
    ("Sancaktepe", "Kartal", {"name": "Samandıra Kartal B."}),
    ("Ataşehir", "Sancaktepe", {"name": "E80"}),
    ("Ataşehir", "Ümraniye", {"name": "O.2"}),
    ("Ataşehir", "Ümraniye",{"name": "E80"}),
    ("Ümraniye", "Sancaktepe", {"name": "E80"}),
    ("Sancaktepe", "Pendik", {"name": "O.7"}),
    ("Sancaktepe", "Pendik", {"name": "D020"}),
    ("Sancaktepe", "Sultanbeyli", {"name": "E80"}),
    ("Sancaktepe", "Sultanbeyli", {"name": "D020"}),
    ("Pendik", "Sultanbeyli", {"name": "E80"}),
    ("Pendik", "Tuzla", {"name": "D100"}),
    ("Pendik", "Tuzla", {"name": "E80"}),
    ("Pendik", "Kartal", {"name": "D100"}),
]

istt.add_edges_from(baglantılar)

# Grafığı çiz
plt.figure(figsize=(100, 100))

# Node etiketlerini belirtmek için kullanılan bir sözlük oluştur
node_labels = {ilçe: ilçe for ilçe in ilçeler}

# Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
edge_labels = {edge[:2]: edge[2]["name"] for edge in istt.edges(data=True)}

# Node'ları ve Edge'leri çiz
pos = nx.spring_layout(istt, seed=50, k=0.3)  # Node'ların konumlarını belirleme, k parametresini ayarlama
nx.draw_networkx_nodes(istt, pos, node_size=10000, node_color="lightblue")
nx.draw_networkx_labels(istt, pos, labels=node_labels, font_size=20, font_color="black")
nx.draw_networkx_edges(istt, pos, edge_color="gray")
nx.draw_networkx_edge_labels(istt, pos, edge_labels=edge_labels, font_size=20, font_color="red")

plt.title("İstanbul Ulaşım Ağı", size=100)
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Grafı oluştur
istt = nx.Graph()

ilçeler = ["Arnavutköy", "Ataşehir", "Avcılar", "Bağcılar", "Bahçelievler",
           "Bakırköy", "Başakşehir", "Bayrampaşa", "Beşiktaş", "Beykoz", "Beylikdüzü",
           "Beyoğlu", "Büyükçekmece", "Çatalca", "Çekmeköy", "Esenler", "Esenyurt",
           "Eyüpsultan", "Fatih", "Gaziosmanpaşa", "Güngören", "Kadıköy", "Kağıthane",
           "Kartal", "Küçükçekmece", "Maltepe", "Pendik", "Sancaktepe", "Sarıyer",
           "Silivri", "Sultanbeyli", "Sultangazi", "Şile", "Şişli", "Tuzla", "Ümraniye",
           "Üsküdar", "Zeytinburnu", '15 Temmuz Şehitler Köprüsü(1.)', 'Fatih Sultan Mehmet Köprüsü(2.)',
           'Yavuz Sultan Selim Köprüsü(3.)', 'Avrasya Tüneli']

istt.add_nodes_from(ilçeler)

# Edge'leri ekle
baglantılar = [
     ("Silivri", "Büyükçekmece", {"name": "D100"}),
    ("Büyükçekmece", "Beylikdüzü", {"name": "E5"}),
    ("Beylikdüzü", "Avcılar", {"name": "E5"}),
    ("Avcılar", "Küçükçekmece", {"name": "E5"}),
    ("Küçükçekmece", "Bahçelievler", {"name": "E5"}),
    ("Bahçelievler", "Güngören", {"name": "E5"}),
    ("Güngören", "Bakırköy", {"name": "E5"}),
    ("Bakırköy", "Bahçelievler", {"name": "E5"}),
    ("Bakırköy", "Zeytinburnu", {"name": "E5"}),
    ("Güngören", "Zeytinburnu", {"name": "E5"}),
    ("Zeytinburnu", "Fatih", {"name": "E5"}),
    ("Fatih", "Avrasya Tüneli", {"name": "Kennedy Cad."}),
    ("Silivri", "Çatalca", {"name": "O.7"}),
    ("Silivri", "Esenyurt", {"name": "E80"}),
    ("Esenyurt", "Arnavutköy", {"name": "E80"}),
    ("Büyükçekmece", "Çatalca", {"name": "D569"}),
    ("Çatalca", "Arnavutköy", {"name": "D020"}),
    ("Çatalca", "Arnavutköy", {"name": "O.7"}),
    ("Arnavutköy", "Sarıyer", {"name": "O.7"}),
    ("Sarıyer", "Yavuz Sultan Selim Köprüsü(3.)", {"name": "O.7"}),
    ("Arnavutköy", "Eyüpsultan", {"name": "D020"}),
    ("Eyüpsultan", "Kağıthane", {"name": "E80"}),
    ("Kağıthane", "Beşiktaş", {"name": "E80"}),
    ("Beşiktaş", "Sarıyer", {"name": "E80"}),
    ("Arnavutköy", "Sultangazi", {"name": "O.7"}),
    ("Sultangazi", "Başakşehir", {"name": "O.7"}),
    ("Sultangazi", "Gaziosmanpaşa", {"name": "E80"}),
    ("Gaziosmanpaşa", "Eyüpsultan", {"name": "E80"}),
    ("Sultangazi", "Eyüpsultan", {"name": "O.7"}),
    ("Başakşehir", "Küçükçekmece", {"name": "O.7"}),
    ("Esenyurt", "Avcılar", {"name": "E80"}),
    ("Avcılar", "Küçükçekmece", {"name": "E80"}),
    ("Küçükçekmece", "Bağcılar", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "E80"}),
    ("Bağcılar", "Esenler", {"name": "O.3"}),
    ("Gaziosmanpaşa", "Esenler", {"name": "E80"}),
    ("Esenler", "Bayrampaşa", {"name": "O.3"}),
    ("Bayrampaşa", "Fatih", {"name": "O.3"}),
    ("Fatih", "Beyoğlu", {"name": "O.1"}),
    ("Beyoğlu", "Şişli", {"name": "O.1"}),
    ("Beyoğlu", "Kağıthane", {"name": "Hasdal O.B."}),
    ("Şişli", "Beşiktaş", {"name": "O.1"}),
    ("Eyüpsultan", "Eyüpsultan", {"name": "D020"}),
    ("Beşiktaş", "15 Temmuz Şehitler Köprüsü(1.)", {"name": "O.1"}),
    ("Sarıyer", "Fatih Sultan Mehmet Köprüsü(2.)", {"name": "E80"}),

    ("Yavuz Sultan Selim Köprüsü(3.)", "Beykoz", {"name": "O.7"}),
    ("Fatih Sultan Mehmet Köprüsü(2.)", "Beykoz", {"name": "E80"}),
    ("15 Temmuz Şehitler Köprüsü(1.)", "Üsküdar", {"name": "O.1"}),
    ("Avrasya Tüneli", "Üsküdar", {"name": "D100"}),
    ("Beykoz", "Çekmeköy", {"name": "O.7"}),
    ("Çekmeköy", "Şile", {"name": "D020"}),
    ("Beykoz", "Ümraniye", {"name": "E80"}),
    ("Çekmeköy", "Ümraniye", {"name": "O.7"}),
    ("Çekmeköy", "Ümraniye", {"name": "D016"}),
    ("Çekmeköy", "Sancaktepe", {"name": "D020"}),
    ("Çekmeköy", "Sancaktepe", {"name": "Şile O."}),
    ("Üsküdar", "Ümraniye", {"name": "O.4"}),
    ("Üsküdar", "Ümraniye", {"name": "Şile O."}),
    ("Üsküdar", "Kadıköy", {"name": "D100"}),
    ("Üsküdar", "Kadıköy", {"name": "O.1"}),
    ("Üsküdar", "Ataşehir", {"name": "O.4"}),
    ("Kadıköy", "Ataşehir", {"name": "O.2"}),
    ("Kadıköy", "Maltepe", {"name": "D100"}),
    ("Maltepe", "Kartal", {"name": "D100"}),
    ("Maltepe", "Kartal", {"name": "Samandıra Kartal B."}),
    ("Sancaktepe", "Kartal", {"name": "Samandıra Kartal B."}),
    ("Ataşehir", "Sancaktepe", {"name": "E80"}),
    ("Ataşehir", "Ümraniye", {"name": "O.2"}),
    ("Ataşehir", "Ümraniye",{"name": "E80"}),
    ("Ümraniye", "Sancaktepe", {"name": "E80"}),
    ("Sancaktepe", "Pendik", {"name": "O.7"}),
    ("Sancaktepe", "Pendik", {"name": "D020"}),
    ("Sancaktepe", "Sultanbeyli", {"name": "E80"}),
    ("Sancaktepe", "Sultanbeyli", {"name": "D020"}),
    ("Pendik", "Sultanbeyli", {"name": "E80"}),
    ("Pendik", "Tuzla", {"name": "D100"}),
    ("Pendik", "Tuzla", {"name": "E80"}),
    ("Pendik", "Kartal", {"name": "D100"}),
]

istt.add_edges_from(baglantılar)

# Grafığı çiz
plt.figure(figsize=(200, 200))

# Node etiketlerini belirtmek için kullanılan bir sözlük oluştur
node_labels = {ilçe: ilçe for ilçe in ilçeler}

# Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
edge_labels = {edge[:3]: edge[3]["name"] for edge in istt.edges(data=True)}

# Her bir etiket için belirlenmiş bir renk listesi
label_colors = {
    "D100": "yellow",
    "E5": "green",
    "E80": "blue",
    "O.7": "purple",
    "O.1": "orange",
    "O.2": "brown",
    "O.3": "pink",
    "O.4": "gray",
    "D020": "black",
    "D569": "cyan",
     "Hasdal O.B.": "magenta",
    "Kennedy Cad." :"Lavender",
    "D016":"black",
 "Şile O.":"black",
     "Samandıra Kartal B.":"black",
}

# Her bir edge'i etiketine göre renklendirelim
edge_colors = [label_colors[edge_labels[edge]] for edge in istt.edges]


pos = nx.spring_layout(istt, seed=50, k=0.3)
nx.draw_networkx_nodes(istt, pos, node_size=30000, node_color="lightblue")
nx.draw_networkx_labels(istt, pos, labels=node_labels, font_size=30, font_color="black", font_weight="bold")  # 'font_weight' parametresi eklenerek
nx.draw_networkx_edges(istt, pos, edge_color=edge_colors, width=2)
nx.draw_networkx_edge_labels(istt, pos, edge_labels=edge_labels, font_size=30, font_color="red",font_weight="bold")

plt.title("İstanbul Ulaşım Ağı", size=150)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-ea6dd91c024b> in <cell line: 110>()
#     108
#     109 # Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
# --> 110 edge_labels = {edge[:3]: edge[3]["name"] for edge in istt.edges(data=True)}
#     111
#     112 # Her bir etiket için belirlenmiş bir renk listesi
#
# <ipython-input-5-ea6dd91c024b> in <dictcomp>(.0)
#     108
#     109 # Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
# --> 110 edge_labels = {edge[:3]: edge[3]["name"] for edge in istt.edges(data=True)}
#     111
#     112 # Her bir etiket için belirlenmiş bir renk listesi
#
# IndexError: tuple index out of range

# %%
# Derece merkeziliklerini hesapla
derece_merkezilik = nx.degree_centrality(istt)

# En yüksek 10 derece merkeziliğine sahip düğümleri bul
en_yuksek_derece_merkezilikleri = sorted(derece_merkezilik.items(), key=lambda x: x[1], reverse=True)[:10]

# Sonuçları yazdır
for ilçe, derece in en_yuksek_derece_merkezilikleri:
    print(f"{derece} = {ilçe}")
# Out:
# 0.14634146341463417 = Eyüpsultan
# 0.14634146341463417 = Sancaktepe
# 0.12195121951219512 = Arnavutköy
# 0.12195121951219512 = Ümraniye
# 0.12195121951219512 = Üsküdar
# 0.0975609756097561 = Ataşehir
# 0.0975609756097561 = Beşiktaş
# 0.0975609756097561 = Beykoz
# 0.0975609756097561 = Çekmeköy
# 0.0975609756097561 = Fatih

# %%
# Yakınlık merkeziliğini hesapla
yakınlık_merkeziliği = nx.closeness_centrality(istt)

# Sonuçları yazdır
for ilçe, yakınlık in yakınlık_merkeziliği.items():
    print(f"{ilçe}: {yakınlık}")
# Out:
# Arnavutköy: 0.2867132867132867
# Ataşehir: 0.2469879518072289
# Avcılar: 0.22527472527472528
# Bağcılar: 0.21465968586387435
# Bahçelievler: 0.211340206185567
# Bakırköy: 0.21693121693121692
# Başakşehir: 0.22404371584699453
# Bayrampaşa: 0.24550898203592814
# Beşiktaş: 0.2867132867132867
# Beykoz: 0.25949367088607594
# Beylikdüzü: 0.1889400921658986
# Beyoğlu: 0.2611464968152866
# Büyükçekmece: 0.205
# Çatalca: 0.23163841807909605
# Çekmeköy: 0.24260355029585798
# Esenler: 0.23976608187134502
# Esenyurt: 0.24848484848484848
# Eyüpsultan: 0.26973684210526316
# Fatih: 0.2751677852348993
# Gaziosmanpaşa: 0.23163841807909605
# Güngören: 0.21693121693121692
# Kadıköy: 0.2342857142857143
# Kağıthane: 0.2789115646258503
# Kartal: 0.19158878504672897
# Küçükçekmece: 0.21465968586387435
# Maltepe: 0.2
# Pendik: 0.19158878504672897
# Sancaktepe: 0.22905027932960895
# Sarıyer: 0.2907801418439716
# Silivri: 0.205
# Sultanbeyli: 0.1889400921658986
# Sultangazi: 0.2578616352201258
# ...

# %%
# Yakınlık merkeziliğini hesapla
yakınlık_merkeziliği = nx.closeness_centrality(istt)

# En yüksek 5 yakınlık merkeziliği değerini bul
en_yüksek_5_ilçe = sorted(yakınlık_merkeziliği.items(), key=lambda x: x[1], reverse=True)[:5]

# Sonuçları yazdır
for sıra, (ilçe, yakınlık) in enumerate(en_yüksek_5_ilçe, start=1):
    print(f"{sıra}. {ilçe}: {yakınlık}")
# Out:
# 1. Sarıyer: 0.2907801418439716
# 2. Arnavutköy: 0.2867132867132867
# 3. Beşiktaş: 0.2867132867132867
# 4. Üsküdar: 0.2847222222222222
# 5. Kağıthane: 0.2789115646258503

# %%
# Arasındalık merkeziliğini hesapla
arasındalık_merkeziliği = nx.betweenness_centrality(istt)

# Sonuçları yazdır
for ilçe, arasındalık in arasındalık_merkeziliği.items():
    print(f"{ilçe}: {arasındalık}")

# %%
# Arasındalık merkeziliğini hesapla
arasındalık_merkeziliği = nx.betweenness_centrality(istt)

# En yüksek 5 arasındalık merkeziliği değerini bul
en_yüksek_5_ilçe = sorted(arasındalık_merkeziliği.items(), key=lambda x: x[1], reverse=True)[:5]

# Sonuçları yazdır
for sıra, (ilçe, arasındalık) in enumerate(en_yüksek_5_ilçe, start=1):
    print(f"{sıra}. {ilçe}: {arasındalık}")
# Out:
# 1. Arnavutköy: 0.29418403133611176
# 2. Sarıyer: 0.268086470360502
# 3. Üsküdar: 0.26604535310058974
# 4. Fatih: 0.22042398260117055
# 5. Sancaktepe: 0.17443635990981762

# %%
import itertools
# Jacard benzerliğini hesapla
jacard_coeff = list(nx.jaccard_coefficient(istt, [(u, v) for u, v in itertools.combinations(istt.nodes(), 2) if u != v]))

# Jacard benzerliği sonuçlarını bir veri çerçevesine dönüştür
df_jacard = pd.DataFrame(jacard_coeff, columns=['Node1', 'Node2', 'Jacard_Similarity'])

# Her iki düğümü de sırala
df_jacard.sort_values(by='Jacard_Similarity', ascending=False, inplace=True)

# Tüm Jacard benzerliği sonuçlarını göster
print(df_jacard.head(10))
# Out:
#                                Node1                           Node2  \
# 858  Fatih Sultan Mehmet Köprüsü(2.)  Yavuz Sultan Selim Köprüsü(3.)
# 681                        Kağıthane                           Şişli
# 696                           Kartal                     Sultanbeyli
# 190                     Bahçelievler                     Zeytinburnu
# 798                      Sultanbeyli                           Tuzla
# 457                          Çatalca                        Esenyurt
# 209                         Bakırköy                        Güngören
# 302                         Beşiktaş                         Beyoğlu
# 18                        Arnavutköy                   Gaziosmanpaşa
# 53                          Ataşehir                        Çekmeköy
#
#      Jacard_Similarity
# 858           1.000000
# 681           0.666667
# 696           0.666667
# 190           0.500000
# 798           0.500000
# 457           0.500000
# 209           0.500000
# ...

# %%
#DERECE MERKEZİLİĞİNE GÖRE ÇİZİM YAPAR
# Grafığı çiz
plt.figure(figsize=(20, 15))

# Node etiketlerini belirtmek için kullanılan bir sözlük oluştur
node_labels = {ilçe: ilçe for ilçe in ilçeler}

# Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
edge_labels = {edge[:2]: edge[2]["name"] for edge in istt.edges(data=True)}
centrality = nx.degree_centrality(istt)
node_sizes = [centrality[node] * 10000 for node in istt.nodes()]
# Node'ları ve Edge'leri çiz
pos = nx.spring_layout(istt, seed=42)  # Node'ların konumlarını belirleme
nx.draw_networkx_nodes(istt, pos, node_size=node_sizes, node_color="lightblue")
nx.draw_networkx_labels(istt, pos, labels=node_labels, font_size=8, font_color="black")
nx.draw_networkx_edges(istt, pos, edge_color="gray")
nx.draw_networkx_edge_labels(istt, pos, edge_labels=edge_labels, font_size=8, font_color="red")

plt.title("İstanbul Ulaşım Ağı", size=20)
plt.axis("off")
plt.show()

# %%
#YAKINLIK MERKEZİLİĞİNE GÖRE ÇİZİM YAPAR
# Grafığı çiz
plt.figure(figsize=(20, 15))

# Node etiketlerini belirtmek için kullanılan bir sözlük oluştur
node_labels = {ilçe: ilçe for ilçe in ilçeler}

# Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
edge_labels = {edge[:2]: edge[2]["name"] for edge in istt.edges(data=True)}
centrality = nx.closeness_centrality(istt)
node_sizes = [centrality[node] * 10000 for node in istt.nodes()]
# Node'ları ve Edge'leri çiz
pos = nx.spring_layout(istt, seed=42)  # Node'ların konumlarını belirleme
nx.draw_networkx_nodes(istt, pos, node_size=node_sizes, node_color="lightblue")
nx.draw_networkx_labels(istt, pos, labels=node_labels, font_size=8, font_color="black")
nx.draw_networkx_edges(istt, pos, edge_color="gray")
nx.draw_networkx_edge_labels(istt, pos, edge_labels=edge_labels, font_size=8, font_color="red")

plt.title("İstanbul Ulaşım Ağı", size=20)
plt.axis("off")
plt.show()

# %%
#ARASINDALIK MERKEZİLİĞİNE GÖRE ÇİZİM YAPAR
# Grafığı çiz
plt.figure(figsize=(20, 15))

# Node etiketlerini belirtmek için kullanılan bir sözlük oluştur
node_labels = {ilçe: ilçe for ilçe in ilçeler}

# Edge etiketlerini belirtmek için kullanılan bir sözlük oluştur
edge_labels = {edge[:2]: edge[2]["name"] for edge in istt.edges(data=True)}
centrality = nx.betweenness_centrality(istt)
node_sizes = [centrality[node] * 10000 for node in istt.nodes()]
# Node'ları ve Edge'leri çiz
pos = nx.spring_layout(istt, seed=42)  # Node'ların konumlarını belirleme
nx.draw_networkx_nodes(istt, pos, node_size=node_sizes, node_color="lightblue")
nx.draw_networkx_labels(istt, pos, labels=node_labels, font_size=8, font_color="black")
nx.draw_networkx_edges(istt, pos, edge_color="gray")
nx.draw_networkx_edge_labels(istt, pos, edge_labels=edge_labels, font_size=8, font_color="red")

plt.title("İstanbul Ulaşım Ağı", size=20)
plt.axis("off")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-a45295c597ff> in <cell line: 22>()
#      20
#      21 # Add cosine similarity values to the DataFrame
# ---> 22 df_cosine['Cosine_Similarity'] = cosine_similarities.flatten()
#      23
#      24 # Sort the DataFrame by cosine similarity in descending order
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# ...

# %%
import networkx as nx

# Graftan bir kopya al (Bu, çizimde kullanılan grafı değiştirmemek içindir)
istt_copy = istt.copy()

# Kümelenme katsayısını hesapla
clustering_coefficient = nx.average_clustering(istt_copy)

print(f"Kümelenme Katsayısı: {clustering_coefficient}")

#0 ile 0.1 arasında: Düşük kümelenme
#0.1 ile 0.5 arasında: Orta düzeyde kümelenme
#0.5 ile 1 arasında: Yüksek kümelenme
# Out:
# Kümelenme Katsayısı: 0.18968253968253967

# %%
import networkx as nx

# Graftan bir kopya al (Bu, çizimde kullanılan grafı değiştirmemek içindir)
istt_copy = istt.copy()

# Grafın çapını hesapla
diameter = nx.diameter(istt_copy)

print(f"Graf Çapı: {diameter}")
# Out:
# Graf Çapı: 10
